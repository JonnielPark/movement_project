# %% [markdown]
# # 01. Data Loading Test
#
# This notebook checks whether the sample pose CSV can be loaded.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebook":
    PROJECT_ROOT = PROJECT_ROOT.parent

from movement.io import load_pose_csv, print_data_summary

csv_path = PROJECT_ROOT / "data/pose/mediapipe/no_consent/20260517/p01_squat_set1_output_pose.csv"

df = load_pose_csv(csv_path)
print_data_summary(df)

df.head()
# Out:
# Data shape: (884, 237)
# Frame range: 0 to 883
# Timestamp range: 0.0 to 29.430969
#    frame  timestamp  frame_width  frame_height  frame_aspect_ratio  \
# 0      0   0.000000         1920          1080            1.777778
# 1      1   0.033331         1920          1080            1.777778
# 2      2   0.066661         1920          1080            1.777778
# 3      3   0.099992         1920          1080            1.777778
# 4      4   0.133323         1920          1080            1.777778
#
#                     coordinate_space  nose_x  nose_y  nose_z  nose_visibility  \
# 0  aspect_corrected_image_normalized     NaN     NaN     NaN              NaN
# 1  aspect_corrected_image_normalized     NaN     NaN     NaN              NaN
# 2  aspect_corrected_image_normalized     NaN     NaN     NaN              NaN
# 3  aspect_corrected_image_normalized     NaN     NaN     NaN              NaN
# 4  aspect_corrected_image_normalized     NaN     NaN     NaN              NaN
#
#    ...  left_foot_index_mp_x  left_foot_index_mp_y  left_foot_index_mp_z  \
# 0  ...                   NaN                   NaN                   NaN
# 1  ...                   NaN                   NaN                   NaN
# 2  ...                   NaN                   NaN                   NaN
# 3  ...                   NaN                   NaN                   NaN
# 4  ...                   NaN                   NaN                   NaN
#
#    right_foot_index_x  right_foot_index_y  right_foot_index_z  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    right_foot_index_visibility  right_foot_index_mp_x  right_foot_index_mp_y  \
# 0                          NaN                    NaN                    NaN
# 1                          NaN                    NaN                    NaN
# 2                          NaN                    NaN                    NaN
# 3                          NaN                    NaN                    NaN
# 4                          NaN                    NaN                    NaN
#
#    right_foot_index_mp_z
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 237 columns]
