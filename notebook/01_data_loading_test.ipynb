# %% [markdown]
# # 01. Data Loading Test
#
# This notebook checks whether the sample pose CSV can be loaded.

# %%
from movement.io import load_pose_csv, print_data_summary

csv_path = "../data/sample/mediapipe_squat_synthetic.csv"

df = load_pose_csv(csv_path)
print_data_summary(df)

df.head()
# Out:
# Data shape: (120, 134)
# Frame range: 0 to 119
# Timestamp range: 0.0 to 3.9667
#    frame  timestamp   nose_x   nose_y   nose_z  nose_visibility  \
# 0      0     0.0000  0.50152  0.18137  0.01269           0.9413
# 1      1     0.0333  0.50199  0.17853  0.00879           0.9640
# 2      2     0.0667  0.50148  0.17711  0.01098           0.9622
# 3      3     0.1000  0.50035  0.17977  0.01165           0.9540
# 4      4     0.1333  0.50187  0.17879  0.00940           0.9770
#
#    left_eye_inner_x  left_eye_inner_y  left_eye_inner_z  \
# 0           0.48808           0.17023           0.01057
# 1           0.49088           0.16868           0.01160
# 2           0.48783           0.17292           0.00888
# 3           0.48961           0.17090           0.00813
# 4           0.49074           0.17317           0.00872
#
#    left_eye_inner_visibility  ...  right_heel_z  right_heel_visibility  \
# 0                     0.9551  ...       0.01897                 0.9653
# ...
