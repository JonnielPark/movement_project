# %% [markdown]
# # 00. Environment Check
#
# - Goal: confirm the Python environment, package import, and default sample paths.
# - Docs: `notebook/README.md`
# - Inputs: Repository root and default sample paths.
# - Outputs: In-memory dataframes/reports unless a cell explicitly saves under `data/processed/`.
# - Checks: Imports, package metadata, and path existence checks.

# %%
import sys
from pathlib import Path

print(sys.executable)
print(Path.cwd())

# %%
import movement

print(movement.__file__)

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "pyproject.toml").exists():
    if PROJECT_ROOT.parent == PROJECT_ROOT:
        raise RuntimeError("Could not find project root containing pyproject.toml")
    PROJECT_ROOT = PROJECT_ROOT.parent

from pathlib import Path

sample_path = PROJECT_ROOT / "data/pose/mediapipe/no_consent/20260517/p01_squat_set1_output_pose.csv"
print(sample_path.resolve())
print("exists:", sample_path.exists())
