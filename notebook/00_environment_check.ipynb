# %% [markdown]
# # 00. Environment Check
#
# This notebook checks whether the package can be imported and whether the sample data path is accessible.
#
# Run this first after cloning the repository and installing the package with:
#
# ```bash
# python -m pip install -e .
# ```

# %%
import sys
from pathlib import Path

print(sys.executable)
print(Path.cwd())
# Out:
# C:\Users\andi9\anaconda3\envs\movement\python.exe
# C:\Users\andi9\Desktop\DEV\source\movement_project\notebook

# %%
import movement

print(movement.__file__)
# Out:
# C:\Users\andi9\Desktop\DEV\source\movement_project\src\movement\__init__.py

# %%
from pathlib import Path

sample_path = Path("../data/sample/mediapipe_forward_bend_sample.csv")
print(sample_path.resolve())
print("exists:", sample_path.exists())
# Out:
# C:\Users\andi9\Desktop\DEV\source\movement_project\data\sample\mediapipe_forward_bend_sample.csv
# exists: True
