# %% [markdown]
# # 00. Environment Check
#
# This notebook checks whether the package can be imported and whether the sample data path is accessible.
#
# Run this first after cloning the repository and installing the package with:
#
# ```bash
# python -m pip install -e .
# ```

# %%
import sys
from pathlib import Path

print(sys.executable)
print(Path.cwd())

# %%
import movement

print(movement.__file__)

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebook":
    PROJECT_ROOT = PROJECT_ROOT.parent

from pathlib import Path

sample_path = PROJECT_ROOT / "data/pose/mediapipe/no_consent/20260517/p01_squat_set1_output_pose.csv"
print(sample_path.resolve())
print("exists:", sample_path.exists())
