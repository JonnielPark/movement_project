# %% [markdown]
# # 10. Scoring Test
#
# This notebook tests the digital biomarker scoring module.
#
# Scoring integrates extracted features and biomechanical proxy outputs into
# repetition-level and session-level interpretable indices — the digital biomarkers.
#
# Scores represent deviation from a reference biomechanical model,
# not absolute clinical measurements.
#
# This notebook assumes that the previous checks are already working:
#
# - 00_environment_check through 09_biomechanical_proxy_test
#
# > **Status:** The `scoring` module is not yet implemented.
# > This notebook is a placeholder and will be updated when the module is ready.
